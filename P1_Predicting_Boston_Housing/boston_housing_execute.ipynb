# %%
# %matplotlib inline
# %run boston_housing_attempt.py
# Out:
# Size of data (number of houses)? 506
# Number of features? 13
# Minimum price? 5.0
# Maximum price? 50.0
# Calculate mean price? 22.5328063241
# Calculate median price? 21.2
# Calculate standard deviation? 9.18801154528
# Decision Tree with Max Depth:
# 1
# boston_housing_attempt.py:104: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   regressor.fit(X_train[:s], y_train[:s])
# boston_housing_attempt.py:107: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   train_err[i] = performance_metric(y_train[:s], regressor.predict(X_train[:s]))
# Decision Tree with Max Depth:
# 2
# Decision Tree with Max Depth:
# 3
# Decision Tree with Max Depth:
# 4
# Decision Tree with Max Depth:
# 5
# Decision Tree with Max Depth:
# 6
# Decision Tree with Max Depth:
# 7
# Decision Tree with Max Depth:
# 8
# Decision Tree with Max Depth:
# 9
# Decision Tree with Max Depth:
# 10
# ...
